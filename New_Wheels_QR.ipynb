# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q1.csv")

# %%
df1
# Out:
#                    state  no_of_customers
# 0             California               97
# 1                  Texas               97
# 2                Florida               86
# 3               New York               69
# 4   District of Columbia               35
# 5               Colorado               33
# 6                   Ohio               33
# 7                Alabama               29
# 8             Washington               28
# 9                Arizona               26
# 10              Illinois               25
# 11          Pennsylvania               25
# 12              Virginia               24
# 13             Tennessee               23
# 14              Missouri               23
# 15           Connecticut               22
# 16               Indiana               21
# 17             Louisiana               20
# 18        North Carolina               20
# 19               Georgia               18
# 20              Michigan               17
# ...

# %%
plt.figure(figsize=(9,9))
sns.barplot(data = df1, x='no_of_customers', y='state', palette ='plasma')
plt.title("Distribution of customers across states in 2018")
plt.xlabel('Number of Customer')
plt.ylabel('State Name')
# Out:
# Text(0, 0.5, 'State Name')

# %%
df2 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q2.csv")

# %%
df2
# Out:
#    year  quarter  rating
# 0  2018        4  2.3970
# 1  2018        1  3.5548
# 2  2018        3  2.9563
# 3  2018        2  3.3550

# %%
sns.barplot(data = df2, x = 'quarter', y = 'rating', palette = 'magma')
plt.title('Average rating in each quarter in 2018')
plt.ylim(0,5)
plt.ylabel('Average Rating')
plt.xlabel('Quarter')
# Out:
# Text(0.5, 0, 'Quarter')

# %%
df3 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q3.csv")

# %%
df3
# Out:
#    year  quarter  good_feedback
# 0  2018        1       30.00000
# 1  2018        2       28.62595
# 2  2018        3       16.59389
# 3  2018        4       10.05025

# %%
sns.lineplot(data=df3, x='quarter', y='good_feedback')
plt.title('Are customers getting more dissatisfied over time?')
plt.ylim(0,35)
plt.xlabel('Qaurter')
plt.ylabel('Customer Feedback')
# Out:
# Text(0, 0.5, 'Customer Feedback')

# %%
df4 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q4.csv")

# %%
df4
# Out:
#   vehicle_model  customer_count
# 0       Century               9
# 1        Camaro               9
# 2    Grand Prix               9
# 3        Galant               8
# 4      SL-Class               8

# %%
sns.barplot(data = df4, x = 'vehicle_model', y = 'customer_count', palette ='coolwarm')
plt.title('Top 5 vehicle makers preferred by the customer')
plt.ylim(0,10)
plt.xlabel('Vehicle Maker')
plt.ylabel('Customer Count')
# Out:
# Text(0, 0.5, 'Customer Count')

# %%
df5 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q5.csv")

# %%
df5
# Out:
#          state vehicle_maker
# 0      Alabama         Dodge
# 1       Alaska     Chevrolet
# 2      Arizona       Pontiac
# 3      Arizona      Cadillac
# 4     Arkansas     Chevrolet
# ..         ...           ...
# 138  Wisconsin         Dodge
# 139  Wisconsin        Nissan
# 140  Wisconsin         Honda
# 141  Wisconsin     Chevrolet
# 142    Wyoming         Buick
#
# [143 rows x 2 columns]

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(10, 6)) 
sns.scatterplot(x='state', y='vehicle_maker', hue='vehicle_maker', data=df5, marker='o', s=100)
plt.title('The most preferred vehicle maker in each state')
plt.xlabel('State')
plt.ylabel('Vehicle Maker')
plt.xticks(rotation=90)
plt.legend(title='vehicle_maker', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
df6 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q6.csv")

# %%
df6
# Out:
#    year  quarter  num_orders
# 0  2018        1         310
# 1  2018        2         262
# 2  2018        3         229
# 3  2018        4         199

# %%
sns.lineplot(data=df6, x='quarter', y='num_orders')
plt.title('The trend of number of orders by quarters in 2018')
plt.xlabel('Quarter')
plt.ylabel('Number of Orders')
# Out:
# Text(0, 0.5, 'Number of Orders')

# %%
df7 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q7.csv")

# %%
df7
# Out:
#    quarter  total_revenue  prev_total_revenue  qoq_percentage_change
# 0        2    21595874.35         26519199.19             -18.565134
# 1        3    19719917.59         21595874.35              -8.686644
# 2        4    15280009.98         19719917.59             -22.514839

# %%
sns.barplot(data = df7, x = 'quarter', y = 'qoq_percentage_change', palette ='Set2')
plt.title('Top 5 vehicle makers preferred by the customer')
# Out:
# Text(0.5, 1.0, 'Top 5 vehicle makers preferred by the customer')

# %%
df8 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q8.csv")

# %%
df8
# Out:
#    year  quarter  order_count  total_revenue
# 0  2018        1          310    26519199.19
# 1  2018        2          262    21595874.35
# 2  2018        3          229    19719917.59
# 3  2018        4          199    15280009.98

# %%
sns.barplot(data = df8, x = 'quarter', y = 'order_count', hue = 'total_revenue', palette ='Set2')
plt.title('The trend of revenue and orders by quarters')
plt.xlabel('Quarter')
plt.ylabel('Number of Orders')
# Out:
# Text(0, 0.5, 'Number of Orders')

# %%
df9 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q9.csv")

# %%
df9
# Out:
#              credit_card_type  average_discount
# 0                         jcb          0.607382
# 1               visa-electron          0.623469
# 2                      switch          0.610233
# 3   diners-club-carte-blanche          0.614490
# 4                       laser          0.643846
# 5              china-unionpay          0.622174
# 6         diners-club-enroute          0.599792
# 7             americanexpress          0.616327
# 8                  mastercard          0.629500
# 9                        visa          0.600833
# 10                   bankcard          0.609545
# 11                       solo          0.585000
# 12                    maestro          0.624219
# 13          diners-club-us-ca          0.614615
# 14               instapayment          0.620625
# 15  diners-club-international          0.584000

# %%
sns.barplot(data = df9, x = 'credit_card_type', y = 'average_discount', palette ='Set2')
plt.xticks(rotation=90);
plt.title('Average discount offered for different types of credit cards')
plt.xlabel('Credit Card Type')
plt.ylabel('Average Discount')
# Out:
# Text(0, 0.5, 'Average Discount')

# %%
df10 = pd.read_csv("~chetandeshpande/Downloads/New_Wheels Q10.csv")

# %%
df10
# Out:
#    year  quarter  avg_shipping_time
# 0  2018        1            57.1677
# 1  2018        2            71.1107
# 2  2018        3           117.7555
# 3  2018        4           174.0955

# %%
sns.regplot(data = df10, x = 'quarter', y = 'avg_shipping_time',  scatter_kws={'s': 50}, line_kws={'color': 'red'})
# Out:
# <AxesSubplot:xlabel='quarter', ylabel='avg_shipping_time'>

# %%
sns.scatterplot(data = df10, x = 'quarter', y = 'avg_shipping_time',  hue = 'avg_shipping_time', palette='Set2')
plt.title('Average time taken to ship the placed orders for each quarters in "Days"')
plt.xlabel('Credit Card Type')
plt.ylabel('Average Discount')
# Out:
# Text(0, 0.5, 'Average Discount')
